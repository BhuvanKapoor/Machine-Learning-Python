# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Data/bhp.csv')
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# 2                4305
# 3                6245
# 4                4250
# ...               ...
# 13195            6689
# 13196           11111
# 13197            5258
# 13198           10407
# 13199            3090
#
# [13200 rows x 7 columns]

# %%
df.shape
# Out:
# (13200, 7)

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
plt.figure(figsize=(10,6))
plt.hist(df.price_per_sqft, bins=20, rwidth=0.8)
# Out:
# (array([1.3196e+04, 2.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([2.67000000e+02, 6.00253650e+05, 1.20024030e+06, 1.80022695e+06,
#         2.40021360e+06, 3.00020025e+06, 3.60018690e+06, 4.20017355e+06,
#         4.80016020e+06, 5.40014685e+06, 6.00013350e+06, 6.60012015e+06,
#         7.20010680e+06, 7.80009345e+06, 8.40008010e+06, 9.00006675e+06,
#         9.60005340e+06, 1.02000401e+07, 1.08000267e+07, 1.14000133e+07,
#         1.20000000e+07]),
#  <BarContainer object of 20 artists>)

# %%
df['zscore'] = (df.price_per_sqft - df.price_per_sqft.mean())/df.price_per_sqft.std()

# %%
df_cleaned = df[(df.zscore > -3) & (df.zscore < 3)]
df_cleaned
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft    zscore
# 0                3699 -0.039553
# 1                4615 -0.030970
# 2                4305 -0.033875
# 3                6245 -0.015697
# 4                4250 -0.034390
# ...               ...       ...
# 13195            6689 -0.011537
# 13196           11111  0.029896
# 13197            5258 -0.024945
# 13198           10407  0.023299
# 13199            3090 -0.045259
#
# [13195 rows x 8 columns]

# %%
df_cleaned.shape
# Out:
# (13195, 8)

# %%
plt.figure(figsize=(10,6))
plt.hist(df_cleaned.price_per_sqft, bins=20, rwidth=0.8)
# Out:
# (array([1.1509e+04, 1.4580e+03, 1.8800e+02, 2.4000e+01, 6.0000e+00,
#         6.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([   267.  ,  10253.65,  20240.3 ,  30226.95,  40213.6 ,  50200.25,
#          60186.9 ,  70173.55,  80160.2 ,  90146.85, 100133.5 , 110120.15,
#         120106.8 , 130093.45, 140080.1 , 150066.75, 160053.4 , 170040.05,
#         180026.7 , 190013.35, 200000.  ]),
#  <BarContainer object of 20 artists>)
